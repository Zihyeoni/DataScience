# %%
import numpy as np
import pandas as pd

# %%
testScores = [28, 35, 26, 32, 28, 28, 35, 34, 46, 42, 37]

# %%
mean = np.mean(testScores)
mean
# Out:
# 33.72727272727273

# %%
std = np.std(testScores)
std
# Out:
# 5.986210048419755

# %%
std_scores = (testScores - mean) / std
std_scores
# Out:
# array([-0.95674436,  0.21260986, -1.29084557, -0.28854195, -0.95674436,
#        -0.95674436,  0.21260986,  0.04555926,  2.05016649,  1.38196408,
#         0.54671107])

# %% [markdown]
# ## Which scores should receive an F?
# 26 (std_scores = -1.29)
