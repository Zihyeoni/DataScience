# %% [markdown]
# # **Linear Regression**

# %%
import pandas as pd
import numpy as np
import io
import warnings
warnings.filterwarnings(action='ignore')

from matplotlib import pyplot as plt

# %%
df = pd.read_csv('linear_regression_data.csv', encoding='utf-8')
df
# Out:
#     Distance  Delivery Time
# 0        100             20
# 1        150             20
# 2        300             36
# 3        400             47
# 4        130             22
# 5        240             31
# 6        350             47
# 7        200             24
# 8        100             19
# 9        110             19
# 10       190             23
# 11       340             39
# 12       130             18
# 13       270             34
# 14       150             21
# 15       255             30
# 16       310             35
# 17       250             28
# 18       150             28
# 19       370             46
# 20       340             36
# 21       280             27
# 22       260             34
# 23       320             37
# 24       170             23
# 25       220             29
# 26       180             22
# 27       210             25
# 28       310             38
# 29       400             50

# %% [markdown]
# predict & evaluate the Delivery time, based on Distance

# %%
X = df['Distance'].values.reshape(-1, 1)
y = df['Delivery Time'].values

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1) test_size = 0.2

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
X_train.shape, y_train.shape
# Out:
# ((24, 1), (24,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lg = LinearRegression()

# %%
lg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(f'''기울기 및 절편 확인
기울기 확인 coef = {lg.coef_}
절편 확인 intercept = {lg.intercept_}''')
# Out:
# 기울기 및 절편 확인
# 기울기 확인 coef = [0.09218785]
# 절편 확인 intercept = 8.166258624527046

# %% [markdown]
# ### predict & evaluation

# %%
y_pred = lg.predict(X_test)

# %%
from sklearn import metrics

# %%
# Result of MAE
metrics.mean_absolute_error(y_test, y_pred)
# Out:
# 2.1484160546034587

# %%
# Result of MSE
metrics.mean_squared_error(y_test, y_pred)
# Out:
# 6.861492459843937

# %%
# Result of RMSE
np.sqrt(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 2.6194450671552434

# %% [markdown]
# ---
#
#
# ## 2) test_size = 0.4

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, shuffle=False)

# %%
X_train.shape, y_train.shape
# Out:
# ((18, 1), (18,))

# %%
lg2 = LinearRegression()

# %%
lg2.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(f'''기울기 및 절편 확인
기울기 확인 coef = {lg2.coef_}
절편 확인 intercept = {lg2.intercept_}''')
# Out:
# 기울기 및 절편 확인
# 기울기 확인 coef = [0.09677206]
# 절편 확인 intercept = 7.129502738105067

# %% [markdown]
# ### predict & evaluation

# %%
y_pred = lg2.predict(X_test)

# %%
# Result of MAE
metrics.mean_absolute_error(y_test, y_pred)
# Out:
# 2.889822229560527

# %%
# Result of MSE
metrics.mean_squared_error(y_test, y_pred)
# Out:
# 12.802216817598122

# %%
# Result of RMSE
np.sqrt(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 3.5780185602646224
